# %% [markdown]
# <a href="https://colab.research.google.com/github/debalinasaha63/Internship-1/blob/main/red_wine_quality_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv('winequality-red.csv')
data.sample(25)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 932             7.6             0.400         0.29            1.90      0.078
# 570            11.5             0.350         0.49            3.30      0.070
# 410             9.0             0.430         0.34            2.50      0.080
# 167             7.3             0.550         0.03            1.60      0.072
# 1331            7.8             0.870         0.26            3.80      0.107
# 42              7.5             0.490         0.20            2.60      0.332
# 1237            7.1             0.750         0.01            2.20      0.059
# 1467            6.7             1.040         0.08            2.30      0.067
# 721             8.9             0.480         0.24            2.85      0.094
# 1469            7.3             0.980         0.05            2.10      0.061
# 427             9.5             0.780         0.22            1.90      0.077
# ...

# %%
# Explore the structure
"Dataset Structure:"
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Explore the dimensions
"\nDataset dimensions:"
data.shape
# Out:
# (1599, 12)

# %%
# Explore the basic statistics
"\nBasic statistics"
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# Check for missing values
"\nMissing values:"
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Explore the distribution of the target variable 'quality'
"\nDistribution of 'quality':"
data['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
data.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
# plot the distribution of 'quality'
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,6))
sns.countplot(x='quality', data=data)
plt.title('Distribution of Wine Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Bar plotting Graphs for Data destribution**

# %%
# fixed acidity v/s quality
plt.figure(figsize=(8,6))
plt.title('Distribution of Fixed Acidity')
sns.barplot(x='quality', y='fixed acidity', data=data)
# Out:
# <Axes: title={'center': 'Distribution of Fixed Acidity'}, xlabel='quality', ylabel='fixed acidity'>

# %%
# volatile acidity v/s quality
plt.figure(figsize=(8,6))
plt.title('Distribution of Volatile acidity')
sns.barplot(x='quality', y='volatile acidity', data=data)
# Out:
# <Axes: title={'center': 'Distribution of Volatile acidity'}, xlabel='quality', ylabel='volatile acidity'>

# %%
# citric acid v/s quality
plt.figure(figsize=(8,6))
plt.title('Distribution of Citric acid')
sns.barplot(x='quality', y='citric acid', data=data)
# Out:
# <Axes: title={'center': 'Distribution of Citric acid'}, xlabel='quality', ylabel='citric acid'>

# %%
# residual sugar v/s quality
plt.figure(figsize=(8,6))
plt.title('Distribution of Residual Sugar')
sns.barplot(x='quality', y='residual sugar', data=data)
# Out:
# <Axes: title={'center': 'Distribution of Residual Sugar'}, xlabel='quality', ylabel='residual sugar'>

# %%
# chlorides v/s quality
plt.figure(figsize=(8,6))
plt.title('Distribution of Chlorides')
sns.barplot(x='quality', y='chlorides', data=data)
# Out:
# <Axes: title={'center': 'Distribution of Chlorides'}, xlabel='quality', ylabel='chlorides'>

# %%
# free sulfur dioxide v/s quality
plt.figure(figsize=(8,6))
plt.title('Distribution of free sulfur dioxide')
sns.barplot(x='quality', y='free sulfur dioxide', data=data)
# Out:
# <Axes: title={'center': 'Distribution of free sulfur dioxide'}, xlabel='quality', ylabel='free sulfur dioxide'>

# %%
# total sulfur dioxide v/s quality
plt.figure(figsize=(8,6))
plt.title('Distribution of total sulfur dioxide')
sns.barplot(x='quality', y='total sulfur dioxide', data=data)
# Out:
# <Axes: title={'center': 'Distribution of total sulfur dioxide'}, xlabel='quality', ylabel='total sulfur dioxide'>

# %%
# density v/s quality
plt.figure(figsize=(8,6))
plt.title('Distribution of density')
sns.barplot(x='quality', y='density', data=data)
# Out:
# <Axes: title={'center': 'Distribution of density'}, xlabel='quality', ylabel='density'>

# %%
# pH v/s quality
plt.figure(figsize=(8,6))
plt.title('Distribution of pH')
sns.barplot(x='quality', y='pH', data=data)
# Out:
# <Axes: title={'center': 'Distribution of pH'}, xlabel='quality', ylabel='pH'>

# %%
# sulphates v/s quality
plt.figure(figsize=(8,6))
plt.title('Distribution of sulphates ')
sns.barplot(x='quality', y='sulphates', data=data)
# Out:
# <Axes: title={'center': 'Distribution of sulphates '}, xlabel='quality', ylabel='sulphates'>

# %%
# alcohol v/s quality
plt.figure(figsize=(8,6))
plt.title('Distribution of alcohol')
sns.barplot(x='quality', y='alcohol', data=data)
# Out:
# <Axes: title={'center': 'Distribution of alcohol'}, xlabel='quality', ylabel='alcohol'>

# %%
# Import necessary libraries
from sklearn.preprocessing import StandardScaler
# Define the cutoff wine quality
cutoff=7
# Convert the quality variable into a binary classification problem
data['quality_binary'] = data['quality'].apply(lambda x: 1 if x >=7 else 0)
# Display the updated dataset
"Updated dataset with binary 'quality_binary' variable:"
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  quality_binary
# 0      9.4        5               0
# ...

# %%
data['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
# If wine quality is 7 or above then will consider as good quality wine
data['goodquality'] = [1 if x >= 7 else 0 for x in data['quality']]
data.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1206            7.2             0.360         0.46             2.1      0.074
# 69              8.0             0.705         0.05             1.9      0.074
# 660             7.2             0.520         0.07             1.4      0.074
# 1204            7.2             0.360         0.46             2.1      0.074
# 1048            9.3             0.490         0.36             1.7      0.081
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1206                 24.0                  44.0  0.99534  3.40       0.85
# 69                    8.0                  19.0  0.99620  3.34       0.95
# 660                   5.0                  20.0  0.99730  3.32       0.81
# 1204                 24.0                  44.0  0.99534  3.40       0.85
# 1048                  3.0                  14.0  0.99702  3.27       0.78
#
#       alcohol  quality  quality_binary  goodquality
# ...

# %%
# Separate features and target variables
X = data.drop(['quality', 'quality_binary'], axis=1)
Y = data['quality_binary']
# Standardize the input features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Display the first rows of the standerdized features
"n\Standardized features"
# Out:
# 'n\\Standardized features'

# %%
pd.DataFrame(X_scaled, columns=X.columns).head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1      -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2      -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3       1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.466193             -0.379133  0.558274  1.288643  -0.579207
# 1             0.872638              0.624363  0.028261 -0.719933   0.128950
# 2            -0.083669              0.229047  0.134264 -0.331177  -0.048089
# 3             0.107592              0.411500  0.664277 -0.979104  -0.461180
# 4            -0.466193             -0.379133  0.558274  1.288643  -0.579207
#
#     alcohol  goodquality
# 0 -0.960246    -0.396256
# ...
